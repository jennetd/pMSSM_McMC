# %%
import matplotlib.pyplot as plt
import math

# %%
def f(x,k):
    return pow(x,k/2.-1.)*np.exp(-1*x/2.)/(pow(2,k/2.)*math.gamma(k/2))

# %%
f(868,107)
# Out:
# 8.2340518033848e-120

# %%
x = np.linspace(1000,0,100)
plt.plot(x,f(x,107))
